# %% [markdown]
# # 2. 자료형
# ## 2.1 숫자

# %%
2+4
# Out:
# 6

# %%
2-4
# Out:
# -2

# %%
2*4
# Out:
# 8

# %%
2/4
# Out:
# 0.5

# %%
2**4 #2의4제곱
# Out:
# 16

# %%
5%3 #5÷2 의 나머지
# Out:
# 2

# %%
5/2 #5÷2
# Out:
# 2.5

# %%
5//2 # 5÷2 의 몫
# Out:
# 2

# %% [markdown]
# ## 2.2 변수

# %%
a=1 #변수 지정

# %%
a #확인
# Out:
# 1

# %% [markdown]
# ### 2.2.1 변수와 문자열 차이

# %%
철수 = 10
print(철수) # 철수
print("철수") # "철수"
# Out:
# 10
# 철수

# %% [markdown]
# ### 2.2.2 이름짓기 규칙

# %%
var=1
var
# Out:
# 1

# %%
변수 = 1
변수
# Out:
# 1

# %%
my_number =1
my_number
# Out:
# 1

# %%
1var=1 # 변수 이름 첫글자에 숫자를 쓸 수 없다.
# Out:
#   File "<ipython-input-15-df9a9e91114d>", line 1
#     1var=1
#        ^
# SyntaxError: invalid syntax

# %%
var-1=1 #변수 이름에 -를 쓸 수 없다.
# Out:
#   File "<ipython-input-17-dbc179af1616>", line 1
#     var-1=1 #변수 이름에 -를 쓸 수 없다.
#                               ^
# SyntaxError: can't assign to operator

# %% [markdown]
# ### 2.2.3 덮어쓰기

# %%
a=1 # a에 1을 넣고
a=100 # 같은 이름을 가진 변수에 100을 넣은 후,
a # a 확인
# Out:
# 100

# %%
a=0  #a는 0
a=a+1 #a에 1을 더한후, a로 저장
a #a를 확인
# Out:
# 1

# %%
a=a+1 # 한번더 1을 더함
a #a를 확인
# Out:
# 2

# %% [markdown]
# ### 2.2.4 여러 변수 지정하기

# %%
a=b=1
a
# Out:
# 1

# %%
b
# Out:
# 1

# %%
a,b=1,2
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
a,b=b,a
a
# Out:
# 2

# %%
b
# Out:
# 1

# %% [markdown]
# ### 2.2.5 Name Error

# %% [markdown]
# 만약 변수명을 정의하지 않고 실행 시킨다면, NameError가 발생한다.

# %%
aa # 정의하지 않은 변수
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-295cb4283a98> in <module>()
# ----> 1 aa # 정의하지 않은 변수
#
# NameError: name 'aa' is not defined

# %% [markdown]
# ### 2.2.6 변수 삭제

# %%
a=1 #a변수 선언
del a # del 내장함수로 삭제
a #a확인
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-f5f13829dd98> in <module>()
#       1 a=1 #a변수 선언
#       2 del a # del 내장함수로 삭제
# ----> 3 a #a확인
#
# NameError: name 'a' is not defined

# %% [markdown]
# ### 2.2.7 연습문제
# 철수는 100만원을 예금하고 연이율 5%의 복리로 10년간 예치하였다고 한다. 철수의 소지 금액은 매년 어떻게 변할지 구하시오.

# %% [markdown]
# ## 2.3 문자
# 문자열은 문자로 이뤄진 자료집합이다.

# %%
'This is a string'
# Out:
# 'This is a string'

# %% [markdown]
# ### 2.3.1 만드는 법
# 문자열은 따옴표를 사용해 만들거나, str 내장함수로 자료형을 바 꿀수 있다.

# %%
a='문자열입니다'

# %%
b="문자열입니다"

# %%
str(123) # 정수를 문자열로
# Out:
# '123'

# %% [markdown]
# 문자열 안에 따옴표를 사용할때는, 문자열이 중간에 끊겨 구문오류가 발생하지 않게 주의를 기울여야 한다.

# %%
"영희가 물었다."철수야,숙제했어?"" #큰 따옴표안에 큰 따옴표 사용
# Out:
#   File "<ipython-input-42-65ce4f4d6f80>", line 1
#     "영희가 물었다."철수야,숙제했어?"" #큰 따옴표안에 큰 따옴표 사용
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# 만약, 문자 열 안에 큰 따옴표를 사용하고 싶다면, 밖에 따옴표를 작은 따옴표로 감싸주면 된다.

# %%
'영희가 물었다. "철수야, 숙제했어?"'  # ' ' 로 " " 감싸기
# Out:
# '영희가 물었다. "철수야, 숙제했어?"'

# %% [markdown]
# 따옴표 세개(""")를 연속으로 사용하면, 다시 따옴표 세 개가 연속으로 나올 때까지 줄바꿈을 포함해서 모든 글자를 문자열로 인식한다.

# %%
"""
영희가 물었다. "철수야, 숙제했어?"
철수는 생각했다. '영희는 숙제를 안하나?'
"""
# Out:
# '\n영희가 물었다. "철수야, 숙제했어?"\n철수는 생각했다. \'영희는 숙제를 안하나?\'\n'

# %% [markdown]
# ### 2.3.2 문자열 표현

# %% [markdown]
# '\n'  # 줄바꿈
# '\t'  # 탭

# %%
print('파이썬\n1. 문자열\n2. 숫자열')
# Out:
# 파이썬
# 1. 문자열
# 2. 숫자열

# %% [markdown]
# ### 2.3.3 문자열 연산

# %%
'1 더하기 1은 ' + '2 입니다'
# Out:
# '1 더하기 1은 2 입니다'

# %%
'하' * 3
# Out:
# '하하하'

# %% [markdown]
# ### 2.3.4 Format
# 문자열에 원하는 값을 대입할 수 있다.
#
# 예를 들어 "안녕하세요 OO님"에 "철수"를 대입할 수 있다.
#
# 만드는 법
# 문자열에 값을 여러 방법으로 대입할 수 있다.
#
# .format()
# 문자열 안에 { } 를 넣어준 후, .format() 을 부르고 안에 원하는 값을 넣는다.

# %%
'제 키는 {}입니다'.format('180 센치')
# Out:
# '제 키는 180 센치입니다'

# %%
'제 키는 {}이며, 몸무게는 {}입니다'.format('180 센치', '비밀')
# Out:
# '제 키는 180 센치이며, 몸무게는 비밀입니다'

# %%
height = '비밀'
weight = '180 센치'

'제 키는 {height}이며, 몸무게는 {weight}입니다'.format(height=height, weight=weight)
# Out:
# '제 키는 비밀이며, 몸무게는 180 센치입니다'

# %% [markdown]
# 파이썬 3.6 부터는 변수명으로 문자열 삽입을 할때 뒤에 .format() 을 붙이지 않고 f' ' 방법으로 직접 대입할 수 있다.

# %%
height = '비밀'
weight = '180 센치'

f'제 키는 {height}이며, 몸무게는 {weight}입니다'
# Out:
# '제 키는 비밀이며, 몸무게는 180 센치입니다'

# %% [markdown]
# ### 2.3.5 문자열 indexing, slicing
# Indexing으로 원하는 자료에 접근할 수 있다.

# %%
a = '마인드스케일'  # 예시 문자열
a[0]  # 문자열 첫 번째 값
# Out:
# '마'

# %%
a[3]  # 문자열 네 번째 값
# Out:
# '스'

# %%
text = 'hello world'  # 예시 문자열 
text[0]  # 문자열 첫 번째 값
# Out:
# 'h'

# %%
text[5]  # 텍스트의 여섯번째 값은,
# Out:
# ' '

# %%
text[-1]  # 문자열 마지막 값
# Out:
# 'd'

# %%
text[-2]  # 문자열 마지막에서 두 번째 값
# Out:
# 'l'

# %% [markdown]
# Slicing으로 자료를 범위로 선택할 수 있다.

# %%
text[0:5]  # 첫 다섯 자료
# Out:
# 'hello'

# %%
text[:5]  # 편의상 0 생략
# Out:
# 'hello'

# %%
text[6:11]  # 7번째 12번째 자료
# Out:
# 'world'

# %%
text[6:]  # 편의상 마지막 숫자 생략
# Out:
# 'world'

# %% [markdown]
# ### 2.3.6 문자열 관련 함수

# %%
#join() 함수는 문자열을 특정글자로 합쳐준다.
','.join('abcd')  # 'abcd' 사이에 쉼표를 추가
# Out:
# 'a,b,c,d'

# %%
#split() 함수는 특정 글자로 문자열을 나눈다.
'사과,오렌지,포도,딸기'.split(',')  # 쉼표를 기준으로 문자열 분리
# Out:
# ['사과', '오렌지', '포도', '딸기']

# %%
#strip() 함수는 문자열 앞뒤의 공백을 치운다.
'    안녕하세요 '.strip()
# Out:
# '안녕하세요'

# %%
#단, 문자열 내부의 빈 공백은 지우지 않는다.
'    안녕하  세요     '.strip()
# Out:
# '안녕하  세요'

# %%
# replace() 함수는 특정 글자를 다른 글자로 바꿔준다.
'안녕하  세요'.replace('  ', '')  # 문자열 중간의 띄어쓰기 교체
# Out:
# '안녕하세요'

# %%
'파이쏜은 참 쉽습니다.'.replace('쏜', '썬')  # '쏜'을 '썬'으로 교체
# Out:
# '파이썬은 참 쉽습니다.'

# %%
#in을 사용해 문자열 안에 해당 글자가 포함되었는지 확인할 수 있다.
'사과' in '오늘의 메뉴는 밥, 미역국, 사과입니다.'  # '사과'가 문자열에 포함되었는지 확인
# Out:
# True

# %%
#not in을 사용해 반대로 해당 글자가 없는지 확인할 수 있다.
'사과' not in '오늘의 메뉴는 밥, 미역국, 사과입니다.'  # '사과'가 문자열에 없는지 확인
# Out:
# False

# %%
#count() 함수는 해당 글자가 문자열에서 몇 번 쓰였는지 확인해준다.
text = 'hello world'
text.count('l')  # 알파벳 'l' 이 몇번 쓰였는지 확인
# Out:
# 3

# %%
#.index() 함수는 해당 글자의 위치를 확인해준다.
text.index('e')  # 'e'의 위치 확인
# Out:
# 1

# %%
#.capitalize() 함수는 문장의 첫 글자를 대문자로 바꾼다.
'hello world'.capitalize()
# Out:
# 'Hello world'

# %%
#.lower() 함수는 모든 글자를 소문자로 바꾼다.
'HeLLO woRlD'.lower()
# Out:
# 'hello world'

# %%
#.upper() 함수는 모든 글자를 대문자로 바꾼다.
'mBc, sBs, Kbs'.upper()
# Out:
# 'MBC, SBS, KBS'

# %%
#startswith() 함수는 문자열이 해당 글자로 시작하는지 확인해준다.
'보고서 작성 중'.startswith('보고서')   # 문자열이 '보고서'로 시작하는지 확인
# Out:
# True

# %%
#.endswith() 함수는 문자열이 해당 글자로 끝나는지 확인해준다.
'보고서 작성 중'.endswith('완료')  # 문자열이 '완료'로 끝나는지 확인
# Out:
# False

# %% [markdown]
# ## 2.4 자료형 변환

# %% [markdown]
# ### 2.4.1 정수로 변환

# %%
int(1.23) #실수를 정수로 변환
# Out:
# 1

# %%
int('123') #문자열을 정수로 변환
# Out:
# 123

# %% [markdown]
# ### 2.4.2 실수로 변환

# %%
float(5) # 정수를 실수로 변환
# Out:
# 5.0

# %%
float('1.23') - 0.1 # 문자열을 실수로 변환
# Out:
# 1.13

# %% [markdown]
# ### 2.4.3 문자열로 변환

# %%
str(5)
# Out:
# '5'

# %%
str(5.0)
# Out:
# '5.0'
